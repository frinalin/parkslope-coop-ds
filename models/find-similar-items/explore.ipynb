# %% [markdown]
# ## Explore Text Embedding for Produce Item Names

# %% [markdown]
# ### Import Data

# %%
import pandas as pd

# %%
# Load data
df = pd.read_csv('../../raw_data/2022-12-07.csv', index_col=0)
df
# Out:
#                                                     Name            Price  \
# 0              Aloe-organic  $1.94 each  Organic, Mexico       $1.94 each
# 1      Apple- Blue pearmain heirloom ipm  $3.34 per p...  $3.34 per pound
# 2      Apple- Calville blanc d'hiver heirloom ipm  $3...  $3.77 per pound
# 3      Apple- Cox's Orange Pippin heirloom label  $3....  $3.34 per pound
# 4      Apple- Golden delicious ipm  $1.50 per pound  ...  $1.50 per pound
# ...                                                  ...              ...
# 11794  Walnuts in shell organic  $4.10 per pound  Org...  $4.10 per pound
# 11795  Watercress-wonder  $1.96 each  Conventional, C...       $1.96 each
# 11796  Wheatgrass-1 lb bags organic  $16.41 each  Org...      $16.41 each
# 11797  Wheatgrass-pots organic  $2.96 each  Organic, ...       $2.96 each
# 11798  Yuca (manioc or cassava)  $1.03 per pound  Con...  $1.03 per pound
#
#                                 Organic?                              Origin  \
# 0                                Organic                              Mexico
# 1      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 2      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 3      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 4      Integrated Pest Management, Waxed  Locally grown within 500 miles USA
# ...                                  ...                                 ...
# 11794                            Organic                                 USA
# 11795                       Conventional                          California
# 11796                            Organic                            New York
# 11797                            Organic                            New York
# 11798                Conventional, Waxed                          Costa Rica
#
#              date                                          item  price  \
# 0      2022-10-30                                Aloe-organic     1.94
# 1      2022-10-30           Apple- Blue pearmain heirloom ipm     3.34
# 2      2022-10-30  Apple- Calville blanc d'hiver heirloom ipm     3.77
# 3      2022-10-30   Apple- Cox's Orange Pippin heirloom label     3.34
# 4      2022-10-30                 Apple- Golden delicious ipm     1.50
# ...           ...                                           ...    ...
# 11794  2022-12-06                    Walnuts in shell organic     4.10
# 11795  2022-12-06                           Watercress-wonder     1.96
# 11796  2022-12-06                Wheatgrass-1 lb bags organic    16.41
# 11797  2022-12-06                     Wheatgrass-pots organic     2.96
# 11798  2022-12-06                    Yuca (manioc or cassava)     1.03
#
#             unit
# 0           each
# 1      per pound
# 2      per pound
# 3      per pound
# 4      per pound
# ...          ...
# 11794  per pound
# 11795       each
# 11796       each
# 11797       each
# 11798  per pound
#
# [11799 rows x 8 columns]

# %% [markdown]
# ### Example 1: SentenceTransformer

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# %%
# create list of cleaned, unique items
df['item_clean']=df['item'].str.lower().str.split('-').str[0] \
                           .str.replace('.', '', regex=False) \
                           .str.strip() \
                           .str.replace(r'\s+', ' ', regex=True)
item_list = df['item_clean'].drop_duplicates().to_list()
item_list
# Out:
# ['aloe',
#  'apple',
#  'artichokes',
#  'arugula',
#  'arugula bunched',
#  'asparagus conventional banded bunched',
#  'avocados',
#  'bananas',
#  'basil',
#  'beans',
#  'beets',
#  'bergamot',
#  'blackberries',
#  'blueberries',
#  'blueberries pint',
#  'bok choy',
#  'broccoli rabe',
#  'broccoli slaw organic',
#  'broccoli',
#  'broccolini',
#  'brussels sprouts loose organic',
#  'brussels sprouts stalks organic',
#  'cabbage',
#  'carrots',
#  'cauliflower',
#  'celeriac',
#  'celery',
#  'chard',
#  'chestnuts',
#  'chicory',
#  'cilantro',
#  'compost',
#  'cranberries',
#  'cucumber',
#  'curry leaf',
#  'daikon',
#  'dandelions',
#  'dill',
#  'eggplant',
#  'endive',
#  'fennel',
#  'flowers',
#  'garlic',
#  'ginger',
#  'gourds',
#  'grapefruit',
#  'grapes',
#  'herbs',
#  'horseradish',
#  'jerusalem artichokes',
#  'jicama',
#  'jujubes',
#  'kale',
#  'kiwi',
#  'kohlrabi',
#  'komatsuna',
#  'leeks',
#  'lemongrass loose',
#  'lemons',
#  'lemons 4958 or blank label',
#  'lettuce',
#  'lime leaf makrut',
#  'limes',
#  'mangos',
#  'melon',
#  'micro greens sampler blue moon pesticide free',
#  'micro greens snow pea perfect foods organic',
#  'micro greens',
#  'mint',
#  'mint bunch',
#  'mizuna',
#  'mushroom',
#  'mustards',
#  'nasturtiums',
#  'nettles (stinging) 4oz organic',
#  'nopales',
#  'onion',
#  'oranges',
#  'oyster leaves 50 ct cup',
#  'papaya',
#  'parsley',
#  'parsnips',
#  'passion fruit',
#  'paw paws wild crafted',
#  'pears',
#  'peas',
#  'peppers',
#  'persimmons',
#  'pineapple',
#  'platanos',
#  'pomegranates 3127',
#  'potatoes',
#  'pumpkin',
#  'quince',
#  'radicchio',
#  'radish',
#  'rambutan',
#  'raspberries',
#  'rutabagas',
#  'salad loose',
#  'salad',
#  'scallions',
#  'shallots',
#  'spinach loose baby organic',
#  'spinach',
#  'sprouts',
#  'squash',
#  'strawberries',
#  'sweet potato',
#  'tangerine',
#  'tatsoi bunch organic',
#  'tomatillos',
#  'tomato cherry little guys organic',
#  'tomato cherry mixed lancaster clamshell organic',
#  'tomato cherry red lancaster organic',
#  'tomato cherry sungold lancaster clamshell organic',
#  'tomato grape other organic',
#  'tomato grape red lancaster organic',
#  'tomato grape sunripe',
#  'tomatoes',
#  'turmeric',
#  'turnips',
#  'watercress',
#  'wheatgrass',
#  'yuca (manioc or cassava)',
#  'burdock root (gobo)',
#  'collards',
#  'escarole',
#  'pea tendrils baby organic',
#  'tomato cherry mix open fiber cup',
#  'pummelo',
#  'starfruit',
#  'okra',
#  'tomato cherry sunset flavor bomb',
#  'walnuts in shell organic',
#  'tomato grape or cherry',
#  "buddha's hand",
#  'medlar',
#  'tomato grape sunset sugar bomb',
#  'tomato grape',
#  'pumpkins',
#  'tomato cherry sunset honey bomb',
#  'tomato cherry sunset lolli bomb',
#  'brussels sprouts',
#  'pomegranates',
#  'kumquats',
#  'apple heirloom',
#  'apple ipm',
#  'clementines',
#  'feijoa',
#  'limequat organic',
#  'plants',
#  'coconut']

# %%
# simple embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(item_list, convert_to_tensor=True)

# %%
# test embeddings
queries = ['tomato', 'oranges', 'broccoli']

top_k=min(5,len(item_list))
for query in queries:
    query_embedding = model.encode(query, convert_to_tensor=True)
    cos_scores = util.cos_sim(query_embedding, embeddings)[0]
    filtered_item_list = [(idx, item) for idx, item in enumerate(item_list) if query.lower() not in item]
    filtered_cos_scores = torch.index_select(cos_scores,
                                             0,
                                             torch.tensor([i[0] for i in filtered_item_list]))
    top_results = torch.topk(filtered_cos_scores, k=top_k)

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar items in item list:")

    for score, idx in zip(top_results[0], top_results[1]):
        print(filtered_item_list[idx][1], "(Score: {:.4f})".format(score))
# Out:
# ======================
#
#
# Query: tomato
#
# Top 5 most similar items in item list:
# grapes (Score: 0.5621)
# plants (Score: 0.5533)
# strawberries (Score: 0.5512)
# pineapple (Score: 0.5497)
# mushroom (Score: 0.5420)
#
#
# ======================
#
#
# Query: oranges
#
# Top 5 most similar items in item list:
# lemons (Score: 0.6273)
# limes (Score: 0.6057)
# pumpkins (Score: 0.5900)
# pears (Score: 0.5457)
# grapes (Score: 0.5384)
#
#
# ======================
#
#
# Query: broccoli
#
# Top 5 most similar items in item list:
# cabbage (Score: 0.6182)
# cauliflower (Score: 0.5494)
# tomatoes (Score: 0.5267)
# brussels sprouts (Score: 0.5143)
# carrots (Score: 0.5137)

# %%
# to productionize:
# pkl the model, embeddings, and item_list
# use flask to create API
# https://www.datacamp.com/tutorial/machine-learning-models-api-python

# %% [markdown]
# ### Example 2: TextVectorization and SpaCy

# %%
# from nltk.corpus import stopwords
from tensorflow.keras.layers import TextVectorization
import tensorflow as tf
import spacy
import numpy as np

# %%
# Clean item names
df['item_clean']=df['item'].str.split('-').str[0]

Vectorizer = TextVectorization(
    standardize='lower_and_strip_punctuation',
    split=None
)
Vectorizer.adapt(df['item_clean'].dropna().to_numpy())
vocab = Vectorizer.get_vocabulary()

# %%
vocab
# Out:
# ['',
#  '[UNK]',
#  'apple',
#  'herbs',
#  'mushroom',
#  'squash',
#  'carrots',
#  'salad',
#  'peppers',
#  'potatoes',
#  'sprouts',
#  'onion',
#  'pears',
#  'lettuce',
#  'cabbage',
#  'micro greens',
#  'salad loose',
#  'sweet potato',
#  'cucumber',
#  'beets',
#  'spinach',
#  'cauliflower',
#  'parsley',
#  'kale',
#  'bok choy',
#  'tomatoes',
#  'garlic',
#  'flowers',
#  'beans',
#  'lemons',
#  'radish',
#  'limes',
#  'persimmons',
#  'tangerine',
#  'platanos',
#  'pineapple',
#  'daikon',
#  'avocados',
#  'turnips',
#  'turmeric',
#  'peas',
#  'ginger',
#  'scallions',
#  'grapes',
#  'dill',
#  'cranberries',
#  'broccoli rabe',
#  'wheatgrass',
#  'broccoli',
#  'bananas',
#  'pumpkin',
#  'radicchio',
#  'mangos',
#  'kohlrabi',
#  'oranges',
#  'watercress',
#  'broccolini',
#  'blueberries',
#  'yuca manioc or cassava  ',
#  'tomato cherry little guys organic  ',
#  'spinach loose baby organic  ',
#  'shallots',
#  'rutabagas',
#  'pomegranates 3127  ',
#  'nopales',
#  'micro greens sampler blue moon pesticide free  ',
#  'lime leaf makrut  ',
#  'lemongrass loose  ',
#  'leeks',
#  'kiwi',
#  'jerusalem artichokes',
#  'grapefruit',
#  'fennel  ',
#  'endive',
#  'curry leaf  ',
#  'cilantro',
#  'chard',
#  'celery',
#  'celeriac',
#  'blueberries pint  ',
#  'blackberries',
#  'basil  ',
#  'asparagus conventional banded bunched  ',
#  'aloe',
#  'shallots  ',
#  'raspberries',
#  'pea tendrils baby organic  ',
#  'parsnips',
#  'papaya',
#  'mint bunch  ',
#  'lemons 4958 or blank label  ',
#  'collards',
#  'chestnuts  ',
#  'burdock root gobo',
#  'arugula bunched  ',
#  'mustards',
#  'eggplant',
#  'dandelions',
#  'compost',
#  'broccoli slaw organic  ',
#  'artichokes  ',
#  'jicama',
#  'escarole  ',
#  'arugula',
#  'walnuts in shell organic  ',
#  'fennel',
#  'tatsoi bunch organic  ',
#  'pummelo',
#  'brussels sprouts loose organic  ',
#  'okra  ',
#  'tomato cherry sunset flavor bomb  ',
#  'gourds',
#  'tomato grape sunset sugar bomb  ',
#  'mint',
#  'tomato grape  ',
#  'tomato cherry sunset lolli bomb  ',
#  'tomato cherry sunset honey bomb  ',
#  'pumpkins',
#  'medlar  ',
#  'komatsuna',
#  'buddhas hand',
#  'brussels sprouts stalks organic  ',
#  'strawberries',
#  'grapefruit  ',
#  'chicory',
#  'cranberries  ',
#  'bergamot  ',
#  'micro greens snow pea perfect foods organic  ',
#  'tomato grape other organic  ',
#  'rambutan  ',
#  'tomatillos  ',
#  'starfruit',
#  'quince',
#  'melon',
#  'horseradish',
#  'brussels sprouts',
#  'tomatillos',
#  'plants',
#  'kumquats',
#  'tomato grape sunripe  ',
#  'passion fruit',
#  'feijoa',
#  'tomato cherry red lancaster organic  ',
#  'oyster leaves 50 ct cup  ',
#  'nettles stinging 4oz organic  ',
#  'nasturtiums',
#  'clementines',
#  'tomato cherry mixed lancaster clamshell organic  ',
#  'tomato cherry sungold lancaster clamshell organic  ',
#  'mizuna',
#  'tomato grape or cherry  ',
#  'tomato cherry mix open fiber cup ',
#  'pomegranates',
#  'bergamot',
#  'tomato grape red lancaster organic  ',
#  'paw paws wild crafted  ',
#  'limequat organic  ',
#  'jujubes',
#  'escarole',
#  'coconut',
#  'apple ipm ',
#  'apple heirloom ']

# %%
# Create embedding matrix
nlp = spacy.load('en_core_web_md')
num_tokens = len(vocab)
embedding_dim = len(nlp('The').vector)
embedding_matrix = np.zeros((num_tokens, embedding_dim))
for i, word in enumerate(vocab):
    embedding_matrix[i] = nlp(str(word)).vector

# %%
# Find similar words
queries = ['tomato', 'oranges', 'broccoli']

top_k=min(5, len(vocab))
for query in queries:
    query_embedding = nlp(query).vector
    cos_scores = tf.keras.losses.cosine_similarity(query_embedding, embedding_matrix.astype('float32'))
    values, indices = tf.math.top_k(-1*cos_scores, k=top_k)
    items = tf.gather(vocab, indices)
    print(items)
# Out:
# tf.Tensor([b'cucumber' b'eggplant' b'tomatillos  ' b'tomatillos' b'tomatoes'], shape=(5,), dtype=string)
# tf.Tensor(
# [b'oranges' b'tomato cherry red lancaster organic  '
#  b'tomato grape red lancaster organic  ' b'lime leaf makrut  '
#  b'tomato cherry sungold lancaster clamshell organic  '], shape=(5,), dtype=string)
# tf.Tensor([b'sprouts' b'cauliflower' b'kale' b'daikon' b'broccoli rabe'], shape=(5,), dtype=string)

# %% [markdown]
# ### Appendix

# %%
# Load embedding matrix as weights matrix for the embedding layer and set trainable to False
Embedding_layer=Embedding(
    num_tokens,
    embedding_dim,
    embeddings_initializer=Constant(embedding_matrix),
    trainable=False)

# %%
#build the model. 
model = Sequential()
model.add(Input(shape=(1,), dtype=tf.string))
model.add(Vectorizer)
model.add(Embedding_layer)

# %%
model.summary()
model('apple'.to_numpy())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  text_vectorization_4 (TextV  (None, None)             0
#  ectorization)
#
#  embedding (Embedding)       (None, None, 300)         2400
#
# =================================================================
# Total params: 2,400
# Trainable params: 0
# Non-trainable params: 2,400
# _________________________________________________________________
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 model.summary()
# ----> 2 model('apple'.to_numpy())
#
# AttributeError: 'str' object has no attribute 'to_numpy'

# %%
# spacy
spacy_model = spacy.load('en_core_web_md')
spacy_embeddings = spacy_model(item_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # spacy
#       2 spacy_model = spacy.load('en_core_web_md')
# ----> 3 spacy_embeddings = spacy_model(item_list)
#
# NameError: name 'item_list' is not defined

# %%
# Create new features with normalized names
df['item_clean']=df['item'].str.lower().str.replace('-', ' ') \
                           .str.replace('.', '') \
                           .str.replace('[', '') \
                           .str.replace(']', '')
df
# Out:
# /var/folders/vs/3x91by114vd3mbjwxgxwcqfc0000gn/T/ipykernel_67841/3989447549.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   .str.replace('.', '') \
# /var/folders/vs/3x91by114vd3mbjwxgxwcqfc0000gn/T/ipykernel_67841/3989447549.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   .str.replace('[', '') \
# /var/folders/vs/3x91by114vd3mbjwxgxwcqfc0000gn/T/ipykernel_67841/3989447549.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   .str.replace(']', '')
#                                                     Name            Price  \
# 0              Aloe-organic  $1.94 each  Organic, Mexico       $1.94 each
# 1      Apple- Blue pearmain heirloom ipm  $3.34 per p...  $3.34 per pound
# 2      Apple- Calville blanc d'hiver heirloom ipm  $3...  $3.77 per pound
# 3      Apple- Cox's Orange Pippin heirloom label  $3....  $3.34 per pound
# 4      Apple- Golden delicious ipm  $1.50 per pound  ...  $1.50 per pound
# ...                                                  ...              ...
# 11794  Walnuts in shell organic  $4.10 per pound  Org...  $4.10 per pound
# 11795  Watercress-wonder  $1.96 each  Conventional, C...       $1.96 each
# 11796  Wheatgrass-1 lb bags organic  $16.41 each  Org...      $16.41 each
# 11797  Wheatgrass-pots organic  $2.96 each  Organic, ...       $2.96 each
# 11798  Yuca (manioc or cassava)  $1.03 per pound  Con...  $1.03 per pound
#
#                                 Organic?                              Origin  \
# 0                                Organic                              Mexico
# 1      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 2      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 3      Integrated Pest Management, Waxed    Scott Farm Orchard Dummerston VT
# 4      Integrated Pest Management, Waxed  Locally grown within 500 miles USA
# ...                                  ...                                 ...
# 11794                            Organic                                 USA
# 11795                       Conventional                          California
# 11796                            Organic                            New York
# 11797                            Organic                            New York
# 11798                Conventional, Waxed                          Costa Rica
#
#              date                                          item  price  \
# 0      2022-10-30                                Aloe-organic     1.94
# 1      2022-10-30           Apple- Blue pearmain heirloom ipm     3.34
# 2      2022-10-30  Apple- Calville blanc d'hiver heirloom ipm     3.77
# 3      2022-10-30   Apple- Cox's Orange Pippin heirloom label     3.34
# 4      2022-10-30                 Apple- Golden delicious ipm     1.50
# ...           ...                                           ...    ...
# 11794  2022-12-06                    Walnuts in shell organic     4.10
# 11795  2022-12-06                           Watercress-wonder     1.96
# 11796  2022-12-06                Wheatgrass-1 lb bags organic    16.41
# 11797  2022-12-06                     Wheatgrass-pots organic     2.96
# 11798  2022-12-06                    Yuca (manioc or cassava)     1.03
#
#             unit                                    item_clean
# 0           each                                aloe organic
# 1      per pound           apple  blue pearmain heirloom ipm
# 2      per pound  apple  calville blanc d'hiver heirloom ipm
# 3      per pound   apple  cox's orange pippin heirloom label
# 4      per pound                 apple  golden delicious ipm
# ...          ...                                           ...
# 11794  per pound                    walnuts in shell organic
# 11795       each                           watercress wonder
# 11796       each                wheatgrass 1 lb bags organic
# 11797       each                     wheatgrass pots organic
# 11798  per pound                    yuca (manioc or cassava)
#
# [11799 rows x 9 columns]

# %%
nlp('organic').vector
# Out:
# array([-2.1983  , -3.6084  , -2.504   ,  2.0542  ,  1.6154  , -2.9402  ,
#         1.3629  ,  1.1536  , -1.5376  , -1.1576  ,  6.2707  , -1.0321  ,
#        -4.4132  ,  3.2919  ,  0.29754 ,  0.73407 ,  2.5348  ,  0.65846 ,
#        -2.5115  , -2.3373  , -2.5962  ,  1.9925  , -3.7461  ,  1.2572  ,
#        -1.4413  , -1.0252  , -0.25379 ,  0.93515 , -4.142   , -1.3918  ,
#         1.8279  , -1.8329  ,  0.14835 , -1.765   , -2.3603  , -3.4326  ,
#         3.2104  , -0.54911 , -3.6038  ,  0.96807 , -0.76069 ,  1.5069  ,
#         0.96726 ,  2.9142  , -2.1434  ,  6.2828  ,  3.8027  , -0.97692 ,
#        -1.4082  ,  0.88415 ,  2.2344  , -0.26386 ,  0.92556 , -0.29604 ,
#        -1.728   , -0.5394  , -1.49    , -0.66376 ,  1.6845  , -3.5032  ,
#         3.7142  ,  0.42245 ,  1.9852  ,  0.43228 ,  0.74296 ,  0.75424 ,
#        -3.6196  , -2.9455  ,  2.7441  ,  0.53157 ,  0.48449 ,  0.55528 ,
#        -2.7062  ,  1.9797  ,  0.46699 ,  2.8114  , -6.1383  ,  0.52034 ,
#        -1.8446  ,  3.4715  , -5.6995  , -0.010747,  0.28906 ,  1.6637  ,
#         0.64367 ,  2.3801  ,  0.29146 , -1.7994  , -1.9243  ,  2.3795  ,
#         0.43165 ,  0.91403 ,  2.776   , -2.1857  ,  0.53833 , -1.7715  ,
#         5.9736  , -1.3039  ,  0.07346 , -2.5043  ,  2.376   , -2.9259  ,
#        -2.1449  ,  2.8033  , -1.0225  ,  5.5529  , -2.5342  , -2.8241  ,
#         0.15093 , -1.859   ,  0.62489 ,  0.49614 , -0.13971 , -4.3621  ,
#        -0.041656,  3.3681  , -1.1327  , -2.8052  , -3.3756  , -1.4071  ,
#        -2.3625  , -2.0203  , -1.5957  ,  2.3279  , -0.1437  , -5.2261  ,
#        -2.8004  , -7.307   ,  3.5933  , -3.5595  , -2.4306  ,  1.354   ,
#         3.5928  , -1.6325  , -2.8209  , -0.11916 , -1.7317  , -2.6646  ,
#        -0.089852,  1.5628  ,  2.4295  , -3.8637  ,  1.5823  ,  2.0316  ,
#         4.0993  , -2.4799  , -2.7713  ,  1.172   ,  3.3214  ,  0.67364 ,
#        -2.2433  ,  5.0587  , -1.2883  , -0.5434  , -4.2004  ,  2.5088  ,
#         6.3192  , -2.187   , -0.95401 , -0.19119 , -2.1446  , -1.8881  ,
#         1.0305  , -0.065673,  1.4607  , -1.1669  , -3.2259  ,  2.8886  ,
#        -1.9632  , -1.4706  , -4.5402  , -0.9376  ,  0.23491 ,  4.8546  ,
#        -0.099641, -0.97911 ,  2.8375  , -0.58327 , -3.1182  , -3.058   ,
#        -4.4917  , -0.12343 , -0.73853 , -4.9095  ,  0.38167 , -3.9167  ,
#        -2.3907  , -0.87255 , -0.084336,  3.894   , -2.0647  , -1.906   ,
#         1.8047  , -1.7392  ,  0.75338 , -0.37502 , -3.6358  , -1.9639  ,
#         2.5195  , -4.4692  , -0.81989 , -2.4798  , -1.183   , -3.3291  ,
#         4.908   , -3.9766  , -5.6297  ,  2.2403  ,  3.0789  , -3.031   ,
#         3.4011  , -0.07691 , -0.007842,  1.4854  , -2.4339  ,  1.1581  ,
#        -0.22446 , -4.5122  , -2.1013  ,  3.3224  , -0.36736 ,  0.8007  ,
#        -2.3986  , -2.1388  , -0.48572 , -0.51282 ,  2.92    ,  2.0048  ,
#         5.1728  ,  1.5472  , -0.28084 , -1.0208  ,  0.21028 ,  5.0753  ,
#         4.6017  , -0.60826 , -2.2851  ,  2.0171  ,  1.4767  , -0.55323 ,
#         0.60744 , -2.926   , -1.8936  ,  2.6463  , -2.4041  ,  2.7704  ,
#        -2.4903  ,  3.3181  ,  2.325   ,  0.49528 , -1.4203  , -0.088647,
#        -6.5279  , -1.2871  , -1.2464  , -2.6299  , -0.70642 ,  3.4665  ,
#        -2.1782  ,  2.3424  , -0.59516 ,  1.0854  , -1.1559  ,  3.5662  ,
#         3.2718  , -1.3317  , -0.81422 ,  0.21225 , -0.91188 , -0.019328,
#        -0.086615,  2.1306  ,  3.3293  ,  4.1627  ,  3.8394  , -0.97828 ,
#         2.4368  ,  0.58367 ,  1.4962  ,  0.014456,  3.2042  ,  0.20174 ,
#         0.69704 , -3.528   ,  1.2664  , -2.2115  , -0.0854  ,  0.043713,
#        -1.1622  ,  2.6088  ,  0.92097 , -1.0834  , -1.9922  , -3.0017  ,
#        -4.3136  , -5.9613  ,  2.9953  , -0.72742 , -0.67599 , -1.599   ],
#       dtype=float32)

# %%
model.fit()

# %%
model.add(LSTM(25, return_sequences=True))
model.add(GlobalMaxPool1D())
model.add(Dropout(0.5))
model.add(Dense(32, activation='tanh', 
                kernel_regularizer = regularizers.l1_l2(l1=1e-5, l2=1e-4)))
model.add(Dropout(0.5))
model.add(Dense(32, activation='tanh', 
                kernel_regularizer = regularizers.l1_l2(l1=1e-5, l2=1e-4)))    
model.add(Dense(1))

adam = optimizers.Adam(learning_rate=.01, decay=1e-2)
model.compile(optimizer = adam, loss = 'mean_absolute_error', metrics = None)

print(model.summary())

#fit the model
model.fit(text.Text,
          text.Grade,
          batch_size = 10,
          epochs = 50,
          validation_split=.2)

# %%
max_features = 5000
max_len = 10

vectorize_layer = tf.keras.layers.TextVectorization(
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=max_len
)

vectorize_layer.adapt(item_list)

model = tf.keras.models.Sequential()
